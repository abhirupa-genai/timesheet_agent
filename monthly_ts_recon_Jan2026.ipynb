# %%
from google import genai
from openai import OpenAI
import ollama
#from google.generativeai import types
import pandas as pd
import json
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv()
# Out:
# True

# %%
try:
    df_ts = pd.read_excel('summarized_timeSheet_Jan2026.xlsx')
    # Optional: Display the first few rows to confirm it loaded correctly
    print("Data loaded successfully:")
    print(df_ts.head())
except FileNotFoundError:
    print(f"Error: summarized_timeSheet_Jan2026.xlsx not found. Please check the file path.")
    exit()
except Exception as e:
    print(f"An error occurred while reading the Excel file: {e}")
    exit()
# Out:
# Data loaded successfully:
#     Timesheet ID NstarX Emp ID             Employee Name Start Date  \
# 0  TS-2025-06345      NSX_0401       Kontham Anand kumar 2026-01-02
# 1  TS-2025-06373      NSX_0178       Swaroopa Vanaparthi 2026-01-02
# 2  TS-2026-00001      NSX_0436            Apparao Buddha 2026-01-02
# 3  TS-2026-00002      NSX_0435  Narayana Reddy Bogireddy 2026-01-02
# 4  TS-2026-00003      NSX_0431        Sai Srinivas Potla 2026-01-02
#
#     End Date  Total Working Hours            Project Name   Client Name  \
# 0 2026-01-02                  8.0       Digital Human 2.0           SHI
# 1 2026-01-02                  8.0                     CMD  Healthstream
# 2 2026-01-02                  8.0  Sustenance Engineering  HealthStream
# 3 2026-01-02                  8.0  Sustenance Engineering  HealthStream
# 4 2026-01-02                  8.0  Sustenance Engineering  HealthStream
#
#      Timesheet Approver Timesheet Status
# 0  Bellum Sai Siva Rama         Approved
# 1      Saiteja Ramagiri         Approved
# 2          Amol Patalay             Open
# 3          Amol Patalay             Open
# 4          Amol Patalay             Open

# %%
try:
    df_emp= pd.read_excel('report.xlsx')

    print("Employees data loaded successfully")
    print(df_emp)

except FileNotFoundError:
    print(f"Error: report.xlsx not found. Please check the file path.")
    exit()
except Exception as e:
    print(f"An error occurred while reading the Excel file: {e}")
    exit()
# Out:
# Employees data loaded successfully
#                  Employee Name                    Employee Email  \
# 0                 Shayne Pinto        shayne.pinto@nstarxinc.com
# 1                Tanishq Swami       tanishq.swami@nstarxinc.com
# 2                         Amol        amol.patalay@nstarxinc.com
# 3             Sachin Chaudhari    sachin.chaudhari@nstarxinc.com
# 4    Sujikar Reddy Varidireddy       sujikar.reddy@nstarxinc.com
# ..                         ...                               ...
# 115              Raju Pasunuri       raju.pasunuri@nstarxinc.com
# 116                Ayush Kumar         ayush.kumar@nstarxinc.com
# 117            Gurunath Kamale     gurunath.kamale@nstarxinc.com
# 118         Srigiri Sai Manish      manish.srigiri@nstarxinc.com
# 119         Vaishnavi Anaboina  vaishnavi.anaboina@nstarxinc.com
#
#                   Manager Name Location
# 0               Ganesh Tyagali       US
# 1    Bommadevara Kavyabharathi    India
# 2                 Vishal Kumar      NaN
# 3                 Vishal Kumar       US
# 4                 Vishal Kumar      NaN
# ..                         ...      ...
# 115                Mohin Shaik    India
# 116                Mohin Shaik    India
# 117                Mohin Shaik    India
# 118                Mohin Shaik    India
# 119                Mohin Shaik    India
#
# [120 rows x 4 columns]

# %%
try:
    df_holidays= pd.read_excel('Holidays_NSX.xlsx')

    print("Holidays data loaded successfully")
    print(df_holidays)

except FileNotFoundError:
    print(f"Error: Holidays_NSX.xlsx not found. Please check the file path.")
    exit()
except Exception as e:
    print(f"An error occurred while reading the Excel file: {e}")
    exit()
# Out:
# Holidays data loaded successfully
#                    Date                          Holiday  \
# 0   2026-01-01 00:00:00       Año nuevo / New Year's Day
# 1   2026-01-02 00:00:00                   Día de la Toma
# 2   2026-01-06 00:00:00               Epifanía del Señor
# 3   2026-01-15 00:00:00               Sankranti / Pongal
# 4   2026-01-26 00:00:00                     Republic Day
# 5   2026-03-03 00:00:00                             Holi
# 6   2026-03-19 00:00:00               Ugadi / Gudi Padwa
# 7   2026-03-27 00:00:00                  Sri Rama Navami
# 8   2026-04-02 00:00:00                     Jueves Santo
# 9   2026-04-03 00:00:00      Viernes Santo / Good Friday
# 10           10-04-2026             Orthodox Good Friday
# 11           13-04-2026           Orthodox Easter Monday
# 12  2026-05-01 00:00:00   Fiesta del Trabajo/ Labour Day
# 13  2026-05-25 00:00:00                     Memorial Day
# 14  2026-05-27 00:00:00             Eid-ul-Zuha (Bakrid)
# 15           01-06-2026                   Children’s Day
# 16  2026-06-04 00:00:00         Fiesta del Corpus Cristi
# 17  2026-07-04 00:00:00                 Independence Day
# 18  2026-08-26 00:00:00                Eid Milad-un-Nabi
# 19  2026-08-28 00:00:00                   Raksha Bandhan
# 20  2026-09-04 00:00:00          Sri Krishna Janmashtami
# 21  2026-09-07 00:00:00                        Labor Day
# 22  2026-09-14 00:00:00               Vinayaka Chaturthi
# 23  2026-10-02 00:00:00           Mahatma Gandhi Jayanti
# 24  2026-10-12 00:00:00        Fiesta Nacional de España
# 25  2026-10-20 00:00:00        Dussehra (Vijaya Dashami)
# 26  2026-11-26 00:00:00                 ThanksGiving Day
# 27  2026-11-27 00:00:00          Day after Thanks Giving
# 28           30-11-2026                 St. Andrew’s Day
# 29           01-12-2026                     National Day
# 30  2026-12-08 00:00:00            Inmaculada Concepción
# 31  2026-12-25 00:00:00  Natividad del Señor / Christmas
# 32           26-12-2026          Second Day of Christmas
#
#                      Location Country Optional Half of Year
# 0   Spain, India, US, Romania, Canada       No          NaN
# 1                      Spain, Romania       No          NaN
# 2                               Spain       No          NaN
# 3                               India       No          NaN
# 4                               India       No          NaN
# 5                               India      Yes   First Half
# 6                               India       No          NaN
# 7                               India      Yes   First Half
# 8                               Spain       No          NaN
# 9                        Spain, India       No          NaN
# 10                            Romania       No          NaN
# 11                            Romania       No          NaN
# 12                     Spain, Romania       No          NaN
# 13                                 US       No          NaN
# 14                              India       No          NaN
# 15                            Romania       No          NaN
# 16                              Spain       No          NaN
# 17                                 US       No          NaN
# 18                              India      Yes  Second Half
# 19                              India      Yes  Second Half
# 20                              India      Yes  Second Half
# 21                         US, Canada      Yes          NaN
# 22                              India       No          NaN
# 23                              India       No          NaN
# 24                              Spain       No          NaN
# 25                              India       No          NaN
# 26                         US, Canada       No          NaN
# 27                                 US       No          NaN
# 28                            Romania       No          NaN
# 29                            Romania       No          NaN
# 30                              Spain       No          NaN
# 31  Spain, Romania, India, US, Canada       No          NaN
# 32                            Romania       No          NaN

# %%
try:
    df_leaves= pd.read_excel('leaves_Jan2026.xlsx')

    print("Leaves data loaded successfully")
    print(df_leaves)

except FileNotFoundError:
    print(f"Error: leave_Jan2026.xlsx not found. Please check the file path.")
    exit()
except Exception as e:
    print(f"An error occurred while reading the Excel file: {e}")
    exit()
# Out:
# Leaves data loaded successfully
#                  name      employee                employee_name  \
# 0   HR-LAP-2026-00002  HR-EMP-00087        Shaurya Prakash Singh
# 1   HR-LAP-2026-00004  HR-EMP-00072           SwamiNaidu Seepana
# 2   HR-LAP-2026-00005  HR-EMP-00011           Subbaraju Chappidi
# 3   HR-LAP-2026-00009  HR-EMP-00149                Naresh Sowoju
# 4   HR-LAP-2026-00012  HR-EMP-00041      Prajakta Shikare Maruti
# ..                ...           ...                          ...
# 91  HR-LAP-2026-00098  HR-EMP-00149                Naresh Sowoju
# 92  HR-LAP-2026-00100  HR-EMP-00040     Tejinderpal Singh Jadhav
# 93  HR-LAP-2026-00107  HR-EMP-00009                 Vishal Kumar
# 94  HR-LAP-2026-00095  HR-EMP-00034      Keertipati Chandu Varma
# 95  HR-LAP-2026-00096  HR-EMP-00157  Sai Vyvaswath Bhupasamudram
#
#                     leave_type  from_date    to_date  total_leave_days  \
# 0    Previous Year Sick Leaves 2026-01-02 2026-01-02               1.0
# 1    Previous Year Sick Leaves 2026-01-02 2026-01-02               1.0
# 2    Previous Year Sick Leaves 2026-01-02 2026-01-02               1.0
# 3                 Earned Leave 2026-01-02 2026-01-02               1.0
# 4    Previous Year Sick Leaves 2026-01-02 2026-01-02               1.0
# ..                         ...        ...        ...               ...
# 91  Previous Year Earned Leave 2026-01-29 2026-01-29               1.0
# 92                  Sick Leave 2026-01-29 2026-01-29               0.5
# 93   Previous Year Sick Leaves 2026-01-29 2026-01-29               0.5
# 94  Previous Year Earned Leave 2026-01-30 2026-01-30               1.0
# 95   Previous Year Sick Leaves 2026-01-30 2026-01-30               1.0
#
#       status
# 0   Approved
# 1   Approved
# 2   Approved
# 3       Open
# 4   Approved
# ..       ...
# 91      Open
# 92  Approved
# 93  Approved
# 94  Approved
# 95  Approved
#
# [96 rows x 8 columns]

# %%
ts_as_csv = df_ts.to_csv(index=False)
emp_as_csv = df_emp.to_csv(index=False)
hol_as_csv = df_holidays.to_csv(index=False)
leaves_as_csv = df_leaves.to_csv(index=False)

# %%
monthly_analysis_prompt = f"""

1. Look into the timesheet records from {ts_as_csv}. 
2. The list of employees is {emp_as_csv}
3. The holidays for each location country is in {hol_as_csv}
4. The list of leaves applied by the employees are in {leaves_as_csv}.
5. The number of working hours in a day is 8 hours. For a given location/country the number of working hours in a month is 
   (total working days in the month - holidays) times 8 hours.
6. Calculate the "required number of working hours in the month" according to step 5.
7. An employee can have multiple rows in {leaves_as_csv}.
8. For every employee calculate the number of leave days in the month by adding the total_leave_days column values.
9. For every employee the "required number of working hours" is "required working hours in the month" - (8 times number of leave days)
10. Employees have their time recorded in muliple rows.
11. For each 'Employee Name' add up the 'Total Working Hours' for all the rows.
12. For each employee calculate "Deficiency/Overtime in  Hours" = required working hours in the month - (8 times number of leaves he/she applied for) 
13. Create a json list output string that can be loaded in a python dictionary. The list should include one dictionary for each employee from {emp_as_csv}.
    The keys for each dictionary should be 
    "Name","Location", "Deficiency/Overtime in Hours", "Total Time Logged","Holiday Hours", "PTO Hours", "Status", "Manager", "Validation Needed","Analysis of Deficiency".
    "Total Time Logged" is same as "Total Working Hours". 
    "Holiday Hours" is 8 times the total number of holidays in the month.
    "PTO Hours" is 8 times the number of leave days in the month for the employee. It is 0 hours for those who have not taken any leave.
    "Status" is same as "Timesheet Status" .
    "Manager is the "Timesheet Approver"
    Include a brief summary of the time logged under "Analysis of Deficiency". 
    If time logged is not equivalet to the required number of hours then set "Validation Needed" to "Yes". Otherwise "No"
    If the logged hours is less than the required number of hours, precede the "Deficiency/Overtime in Hours" with a '-'
    If the logged hours is more than the required number of hours, precede the "Deficiency/Overtime in Hours" with a '+'

12. Do not include any string in the response apart from the json list. 
"""

# %%
try:
    api_key = os.getenv("GEMINI_API_KEY")
    if not api_key:
        raise ValueError("GEMINI_API_KEY environment variable not set.")
    client = genai.Client(api_key=api_key)
except ValueError as e:
    print(f"Configuration error: {e}")
    exit()

# %%
response = client.models.generate_content(
    model="gemini-3-flash-preview", # Or a more powerful model like gemini-2.5-pro for complex analysis
    contents=monthly_analysis_prompt
    
    
)

# %%
print("\n--- Employees who missed to enter timesheets---")
analysis_result = response.text
print(analysis_result)
# Out:
# --- Employees who missed to enter timesheets---
# [
#   {
#     "Name": "Shayne Pinto",
#     "Location": "US",
#     "Deficiency/Overtime in Hours": "-108.0",
#     "Total Time Logged": 60.0,
#     "Holiday Hours": 8,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Ganesh Tyagali",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 60 hours out of the adjusted requirement of 168 hours."
#   },
#   {
#     "Name": "Tanishq Swami",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Bommadevara Kavyabharathi",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged for the month."
#   },
#   {
#     "Name": "Amol",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-144.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Open",
#     "Manager": "Vishal Kumar",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Applied for 1 day of leave but logged 0 working hours."
#   },
#   {
#     "Name": "Sachin Chaudhari",
#     "Location": "US",
#     "Deficiency/Overtime in Hours": "-168.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 8,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Vishal Kumar",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged for the month."
#   },
#   {
#     "Name": "Sujikar Reddy Varidireddy",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-24.0",
#     "Total Time Logged": 112.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 16,
#     "Status": "Open",
#     "Manager": "Vishal Kumar",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 112 hours against an adjusted requirement of 136 hours."
#   },
#   {
#     "Name": "Younus Shaik",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 152.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Vishal Kumar",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match the monthly requirement."
#   },
#   {
#     "Name": "Manjrekar Manish Raj",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-72.0",
#     "Total Time Logged": 80.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Vishal Kumar",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Only 80 hours logged out of the required 152."
#   },
#   {
#     "Name": "Bellum Sai Siva Rama Krishna",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 148.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 4,
#     "Status": "Approved",
#     "Manager": "Vishal Kumar",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after accounting for 0.5 days of leave."
#   },
#   {
#     "Name": "Mohin Shaik",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 152.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Vishal Kumar",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match the monthly requirement."
#   },
#   {
#     "Name": "Subbaraju",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-8.0",
#     "Total Time Logged": 120.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 24,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 120 hours; requirement after 3 days of leave was 128 hours."
#   },
#   {
#     "Name": "Nidhi",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Swaroopa",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-8.0",
#     "Total Time Logged": 136.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Saiteja Ramagiri",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 136 hours against an adjusted requirement of 144 hours."
#   },
#   {
#     "Name": "Ramagiri Saiteja",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 148.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 4,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 0.5 days leave."
#   },
#   {
#     "Name": "Smruthi Kothakonda",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-40.0",
#     "Total Time Logged": 112.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 112 hours out of the required 152."
#   },
#   {
#     "Name": "Sravani Koukuntla",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-72.0",
#     "Total Time Logged": 80.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 80 hours out of the required 152."
#   },
#   {
#     "Name": "Jabeen Khanam",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 152.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match the monthly requirement."
#   },
#   {
#     "Name": "Uday kiran Y",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 1 day of leave."
#   },
#   {
#     "Name": "Rajan Kumar",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-136.0",
#     "Total Time Logged": 8.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Saiteja Ramagiri",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Only 8 hours logged for the entire month."
#   },
#   {
#     "Name": "Dosala Shiva Shankaraiah",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 152.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match the monthly requirement."
#   },
#   {
#     "Name": "Arun Goluguri",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Saketh Dahagam",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 152.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match the monthly requirement."
#   },
#   {
#     "Name": "Veena Madhuri",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Naveen Babu Yarlagadda",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Nagasandeep Motupalli",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 152.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match the monthly requirement."
#   },
#   {
#     "Name": "Shravan Kumar A S",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Hariteja Eeraparaju",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Suresh Goparaju",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 152.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Chappidi Subba Raju",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements."
#   },
#   {
#     "Name": "Venkat Pogakula",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-85.0",
#     "Total Time Logged": 67.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 67 hours out of required 152."
#   },
#   {
#     "Name": "Thota Naresh",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 136.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 16,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 2 days of leave."
#   },
#   {
#     "Name": "Ashok Munagala",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "+48.0",
#     "Total Time Logged": 176.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 24,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Overtime of 48 hours logged."
#   },
#   {
#     "Name": "Sampath Gattu",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-8.0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Chappidi Subba Raju",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 144 hours against required 152."
#   },
#   {
#     "Name": "Deepak Devaraj",
#     "Location": "US",
#     "Deficiency/Overtime in Hours": "+8.0",
#     "Total Time Logged": 176.0,
#     "Holiday Hours": 8,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Amol  Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Overtime of 8 hours logged against requirement of 168."
#   },
#   {
#     "Name": "Sai Srinivas Potla",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "+32.0",
#     "Total Time Logged": 152.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 32,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged full month hours despite 4 days of leave."
#   },
#   {
#     "Name": "Geethika Kakarla",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 136.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 16,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 2 days of leave."
#   },
#   {
#     "Name": "Narayana Reddy Bogireddy",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 136.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 16,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 2 days of leave."
#   },
#   {
#     "Name": "Apparao Buddha",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 1 day leave."
#   },
#   {
#     "Name": "Ganesh Vallamla",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 136.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 16,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 2 days leave."
#   },
#   {
#     "Name": "Sriram Narayan",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Venkat Murthy Velamala",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 136.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 16,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 2 days leave."
#   },
#   {
#     "Name": "Chaitanya Dhanalakota",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Tejaswini Kande",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Subbaraju Chappidi",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Sirisha Achnala",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 152.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Chappidi Subba Raju",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements."
#   },
#   {
#     "Name": "Siva Reddy Evuri",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Chappidi Subba Raju",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 1 day leave."
#   },
#   {
#     "Name": "Kotla Pavani Priyanka",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 152.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Chappidi Subba Raju",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements."
#   },
#   {
#     "Name": "SwamiNaidu Seepana",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 136.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 16,
#     "Status": "Approved",
#     "Manager": "Chappidi Subba Raju",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 2 days leave."
#   },
#   {
#     "Name": "Raghava Harshavardhan Raju",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 120.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 32,
#     "Status": "Approved",
#     "Manager": "Chappidi Subba Raju",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 4 days leave."
#   },
#   {
#     "Name": "Mohd Khaja Shujauddin",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Saiteja Ramagiri",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 1 day leave."
#   },
#   {
#     "Name": "Tejaswani Kambampati",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-24.0",
#     "Total Time Logged": 108.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 20,
#     "Status": "Approved",
#     "Manager": "Saiteja Ramagiri",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 108 hours against adjusted requirement of 132."
#   },
#   {
#     "Name": "Keertipati Chandu Varma",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 128.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 24,
#     "Status": "Approved",
#     "Manager": "Saiteja Ramagiri",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 3 days leave."
#   },
#   {
#     "Name": "Chandana Gidugu",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 152.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Saiteja Ramagiri",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements."
#   },
#   {
#     "Name": "Prajakta Shikare Maruti",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Saiteja Ramagiri",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 1 day leave."
#   },
#   {
#     "Name": "Amar Sai Veeravalli",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-40.0",
#     "Total Time Logged": 96.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 16,
#     "Status": "Approved",
#     "Manager": "Saiteja Ramagiri",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 96 hours out of adjusted required 136."
#   },
#   {
#     "Name": "Sai Krishna Andhavarapu",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "+16.0",
#     "Total Time Logged": 168.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Saiteja Ramagiri",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Overtime of 16 hours logged."
#   },
#   {
#     "Name": "Anveshitha Thota",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 152.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Saiteja Ramagiri",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirement."
#   },
#   {
#     "Name": "Nuty Vanitha",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Smruthi Kothakonda",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirement after 1 day leave."
#   },
#   {
#     "Name": "Devadula Sai Sudheer",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Smruthi Kothakonda",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirement after 1 day leave."
#   },
#   {
#     "Name": "Gouni Saideepthi",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Smruthi Kothakonda",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Bera Sireesha Krishnaveni",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Smruthi Kothakonda",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Venkata Lalitha Suresh Emani",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirement after 1 day leave."
#   },
#   {
#     "Name": "Sindhu Pogula",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-36.0",
#     "Total Time Logged": 96.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 20,
#     "Status": "Open",
#     "Manager": "Uday kiran Y",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 96 hours out of adjusted required 132."
#   },
#   {
#     "Name": "Ramesh Bevara",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "+8.0",
#     "Total Time Logged": 160.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Overtime of 8 hours logged."
#   },
#   {
#     "Name": "Naresh Sowoju",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 128.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 24,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirement after 3 days leave."
#   },
#   {
#     "Name": "Rajeshwar",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-144.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Syam Sundar Devarakonda",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged despite 1 day of leave."
#   },
#   {
#     "Name": "Pramod Kumar Kodoju",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Syam Devarakonda",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirement after 1 day leave."
#   },
#   {
#     "Name": "Babita Kumar",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Syam Sundar Devarakonda",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Jesus Fernandez",
#     "Location": "Spain",
#     "Deficiency/Overtime in Hours": "-40.0",
#     "Total Time Logged": 112.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Suman Kalyan",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 112 hours against monthly requirement of 152."
#   },
#   {
#     "Name": "Vishal Kumar",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "+28.0",
#     "Total Time Logged": 168.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 12,
#     "Status": "Approved",
#     "Manager": "Angshuman Patra",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Overtime of 28 hours logged."
#   },
#   {
#     "Name": "Syam Sundar Devarakonda",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-40.0",
#     "Total Time Logged": 104.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Angshuman Patra",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 104 hours out of adjusted required 144."
#   },
#   {
#     "Name": "Sneha Sahu",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-52.0",
#     "Total Time Logged": 100.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 100 hours out of required 152."
#   },
#   {
#     "Name": "Vaibhav Mittal",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-48.0",
#     "Total Time Logged": 104.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Bellum Sai Siva Rama",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 104 hours out of required 152."
#   },
#   {
#     "Name": "Nikhil Sham Vanjari",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Sujikar Reddy Varidireddy",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Kontham Anand kumar",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-2.0",
#     "Total Time Logged": 142.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Bellum Sai Siva Rama",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 142 hours against adjusted required 144."
#   },
#   {
#     "Name": "Shriyans Kandhagatla",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-2.716112",
#     "Total Time Logged": 149.283888,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Bellum Sai Siva Rama",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Slight deficiency in total hours logged."
#   },
#   {
#     "Name": "Arya Pulkit",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 1 day leave."
#   },
#   {
#     "Name": "Sreelakshmi Kammakattu",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-130.333333",
#     "Total Time Logged": 13.666667,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Only ~13.7 hours logged for the month."
#   },
#   {
#     "Name": "Britney H",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Sujikar Reddy Varidireddy",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Sai Vyvaswath Bhupasamudram",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirement after 1 day leave."
#   },
#   {
#     "Name": "Kriti Bhagat",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-81.117222",
#     "Total Time Logged": 70.882778,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 70.88 hours out of required 152."
#   },
#   {
#     "Name": "Debopriyo Ghosh",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Sujikar Reddy Varidireddy",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "K Anjali Achary",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "+32.0",
#     "Total Time Logged": 176.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Younus Shaik",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Overtime of 32 hours logged."
#   },
#   {
#     "Name": "Meena Nagarajan",
#     "Location": "US",
#     "Deficiency/Overtime in Hours": "-48.0",
#     "Total Time Logged": 120.0,
#     "Holiday Hours": 8,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 120 hours against requirement of 168."
#   },
#   {
#     "Name": "Navdeep Singh",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-118.666667",
#     "Total Time Logged": 33.333333,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Sujay Kumar",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 33.33 hours out of required 152."
#   },
#   {
#     "Name": "Jhanvi Sharma",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "+24.416667",
#     "Total Time Logged": 176.416667,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Sujay Kumar",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Overtime of 24.42 hours logged."
#   },
#   {
#     "Name": "Saloni Singh Andotra",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Sujay Kumar",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Anchal Bakshi",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Sujay Kumar",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Afrin Taj",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Sujay Kumar",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Sarika Sharma",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "+25.054485",
#     "Total Time Logged": 177.054485,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Sujay Kumar",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Overtime of 25.05 hours logged."
#   },
#   {
#     "Name": "MN Prasad Reddy",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Sujay Kumar",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Dakshina Murthy Karra",
#     "Location": "US",
#     "Deficiency/Overtime in Hours": "-168.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 8,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Babita Kumar",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Adrian Paleacu",
#     "Location": "Romania",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 160.0,
#     "Holiday Hours": 16,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Dakshina Murthy Karra",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match monthly requirement."
#   },
#   {
#     "Name": "Gabriel Trautmann",
#     "Location": "Romania",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 160.0,
#     "Holiday Hours": 16,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Dakshina Murthy Karra",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match monthly requirement."
#   },
#   {
#     "Name": "Sidharth Kondapuram",
#     "Location": "Spain",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Jesus Fernandez",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Akunuri Jai Tiru Ganesh",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-2.5",
#     "Total Time Logged": 121.5,
#     "Holiday Hours": 24,
#     "PTO Hours": 28,
#     "Status": "Open",
#     "Manager": "Manjrekar Manish Raj",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 121.5 hours against adjusted requirement of 124."
#   },
#   {
#     "Name": "Abhirupa Sen",
#     "Location": "US",
#     "Deficiency/Overtime in Hours": "-168.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 8,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Shayne Pinto",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Kotturi Supriya",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "+0.166666",
#     "Total Time Logged": 144.166666,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Bellum Sai Siva Rama Krishna",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Slight overtime of 0.17 hours."
#   },
#   {
#     "Name": "Sai Shiva Naga Gudla",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Bellum Sai Siva Rama",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirement after 1 day leave."
#   },
#   {
#     "Name": "Sanket Khushal Patil",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-10.0",
#     "Total Time Logged": 134.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Bellum Sai Siva Rama",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 134 hours out of adjusted requirement of 144."
#   },
#   {
#     "Name": "Vikram Dattatray Danvale",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-59.5",
#     "Total Time Logged": 84.5,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Bellum Sai Siva Rama",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 84.5 hours out of adjusted requirement of 144."
#   },
#   {
#     "Name": "Rishi Soni",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-0.334445",
#     "Total Time Logged": 147.665555,
#     "Holiday Hours": 24,
#     "PTO Hours": 4,
#     "Status": "Approved",
#     "Manager": "Bellum Sai Siva Rama",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Slight deficiency in hours logged."
#   },
#   {
#     "Name": "Suneel Kumar Reddy Vaka",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-32.0",
#     "Total Time Logged": 88.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 32,
#     "Status": "Approved",
#     "Manager": "Bellum Sai Siva Rama",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 88 hours against adjusted requirement of 120."
#   },
#   {
#     "Name": "Manish Gari",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "+6.0",
#     "Total Time Logged": 150.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Bellum Sai Siva Rama",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 150 hours against adjusted requirement of 144."
#   },
#   {
#     "Name": "Yassir Benhammou",
#     "Location": "Spain",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 152.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirement."
#   },
#   {
#     "Name": "Bommadevara Kavyabharathi",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-2.0",
#     "Total Time Logged": 122.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 28,
#     "Status": "Approved",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 122 hours against adjusted requirement of 124."
#   },
#   {
#     "Name": "Tejinderpal Singh Jadhav",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-96.0",
#     "Total Time Logged": 40.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 16,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 40 hours against adjusted requirement of 136."
#   },
#   {
#     "Name": "Rohit Kumar",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Shantanu Chaturvedi",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   },
#   {
#     "Name": "Venkata Santosh Krishna Teja Ghanta",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "+8.0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 16,
#     "Status": "Open",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 144 hours against adjusted requirement of 136."
#   },
#   {
#     "Name": "Inguva Satyavenkata Sai Kumar",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 112.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 40,
#     "Status": "Approved",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 5 days leave."
#   },
#   {
#     "Name": "Chowdarapu Srivatsa",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-32.0",
#     "Total Time Logged": 120.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 120 hours out of required 152."
#   },
#   {
#     "Name": "Heet Hiteshkumar Gorakhiya",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-135.75",
#     "Total Time Logged": 8.25,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Open",
#     "Manager": "Sachin Chaudhari",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Only 8.25 hours logged."
#   },
#   {
#     "Name": "Shaurya Prakash Singh",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-144.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "N/A",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Applied for leave but logged no hours."
#   },
#   {
#     "Name": "Rahul Holekeri",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-14.5",
#     "Total Time Logged": 121.5,
#     "Holiday Hours": 24,
#     "PTO Hours": 16,
#     "Status": "Approved",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 121.5 hours out of adjusted requirement of 136."
#   },
#   {
#     "Name": "Suresh Babu Konapuram",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 136.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 16,
#     "Status": "Approved",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements after 2 days leave."
#   },
#   {
#     "Name": "Alessandro Tiberio",
#     "Location": "Spain",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 152.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Open",
#     "Manager": "Dakshina Murthy Karra",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirements."
#   },
#   {
#     "Name": "Sowmya Kunapuli",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-8.0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "Approved",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 144 hours out of required 152."
#   },
#   {
#     "Name": "Raju Pasunuri",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "0",
#     "Total Time Logged": 144.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "No",
#     "Analysis of Deficiency": "Logged hours match requirement after 1 day leave."
#   },
#   {
#     "Name": "Ayush Kumar",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-8.0",
#     "Total Time Logged": 136.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 136 hours against adjusted requirement of 144."
#   },
#   {
#     "Name": "Gurunath Kamale",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-8.0",
#     "Total Time Logged": 136.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Approved",
#     "Manager": "Amol Patalay",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 136 hours against adjusted requirement of 144."
#   },
#   {
#     "Name": "Srigiri Sai Manish",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-88.0",
#     "Total Time Logged": 56.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 8,
#     "Status": "Open",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "Logged 56 hours out of adjusted requirement of 144."
#   },
#   {
#     "Name": "Vaishnavi Anaboina",
#     "Location": "India",
#     "Deficiency/Overtime in Hours": "-152.0",
#     "Total Time Logged": 0.0,
#     "Holiday Hours": 24,
#     "PTO Hours": 0,
#     "Status": "N/A",
#     "Manager": "Mohin Shaik",
#     "Validation Needed": "Yes",
#     "Analysis of Deficiency": "No hours logged."
#   }
# ]

# %%
emp_lst = json.loads(analysis_result)

# %%
print(len(emp_lst))
for dict in emp_lst:
    print(dict)
# Out:
# 120
# {'Name': 'Shayne Pinto', 'Location': 'US', 'Deficiency/Overtime in Hours': '-108.0', 'Total Time Logged': 60.0, 'Holiday Hours': 8, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Ganesh Tyagali', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 60 hours out of the adjusted requirement of 168 hours.'}
# {'Name': 'Tanishq Swami', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Bommadevara Kavyabharathi', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged for the month.'}
# {'Name': 'Amol', 'Location': 'India', 'Deficiency/Overtime in Hours': '-144.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Open', 'Manager': 'Vishal Kumar', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Applied for 1 day of leave but logged 0 working hours.'}
# {'Name': 'Sachin Chaudhari', 'Location': 'US', 'Deficiency/Overtime in Hours': '-168.0', 'Total Time Logged': 0.0, 'Holiday Hours': 8, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Vishal Kumar', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged for the month.'}
# {'Name': 'Sujikar Reddy Varidireddy', 'Location': 'India', 'Deficiency/Overtime in Hours': '-24.0', 'Total Time Logged': 112.0, 'Holiday Hours': 24, 'PTO Hours': 16, 'Status': 'Open', 'Manager': 'Vishal Kumar', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 112 hours against an adjusted requirement of 136 hours.'}
# {'Name': 'Younus Shaik', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 152.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Vishal Kumar', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match the monthly requirement.'}
# {'Name': 'Manjrekar Manish Raj', 'Location': 'India', 'Deficiency/Overtime in Hours': '-72.0', 'Total Time Logged': 80.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Vishal Kumar', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Only 80 hours logged out of the required 152.'}
# {'Name': 'Bellum Sai Siva Rama Krishna', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 148.0, 'Holiday Hours': 24, 'PTO Hours': 4, 'Status': 'Approved', 'Manager': 'Vishal Kumar', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after accounting for 0.5 days of leave.'}
# {'Name': 'Mohin Shaik', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 152.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Vishal Kumar', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match the monthly requirement.'}
# {'Name': 'Subbaraju', 'Location': 'India', 'Deficiency/Overtime in Hours': '-8.0', 'Total Time Logged': 120.0, 'Holiday Hours': 24, 'PTO Hours': 24, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 120 hours; requirement after 3 days of leave was 128 hours.'}
# {'Name': 'Nidhi', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Swaroopa', 'Location': 'India', 'Deficiency/Overtime in Hours': '-8.0', 'Total Time Logged': 136.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Saiteja Ramagiri', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 136 hours against an adjusted requirement of 144 hours.'}
# {'Name': 'Ramagiri Saiteja', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 148.0, 'Holiday Hours': 24, 'PTO Hours': 4, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 0.5 days leave.'}
# {'Name': 'Smruthi Kothakonda', 'Location': 'India', 'Deficiency/Overtime in Hours': '-40.0', 'Total Time Logged': 112.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 112 hours out of the required 152.'}
# {'Name': 'Sravani Koukuntla', 'Location': 'India', 'Deficiency/Overtime in Hours': '-72.0', 'Total Time Logged': 80.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 80 hours out of the required 152.'}
# {'Name': 'Jabeen Khanam', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 152.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match the monthly requirement.'}
# {'Name': 'Uday kiran Y', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 1 day of leave.'}
# {'Name': 'Rajan Kumar', 'Location': 'India', 'Deficiency/Overtime in Hours': '-136.0', 'Total Time Logged': 8.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Saiteja Ramagiri', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Only 8 hours logged for the entire month.'}
# {'Name': 'Dosala Shiva Shankaraiah', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 152.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match the monthly requirement.'}
# {'Name': 'Arun Goluguri', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Saketh Dahagam', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 152.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match the monthly requirement.'}
# {'Name': 'Veena Madhuri', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Naveen Babu Yarlagadda', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Nagasandeep Motupalli', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 152.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match the monthly requirement.'}
# {'Name': 'Shravan Kumar A S', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Hariteja Eeraparaju', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Suresh Goparaju', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 152.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Chappidi Subba Raju', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements.'}
# {'Name': 'Venkat Pogakula', 'Location': 'India', 'Deficiency/Overtime in Hours': '-85.0', 'Total Time Logged': 67.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 67 hours out of required 152.'}
# {'Name': 'Thota Naresh', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 136.0, 'Holiday Hours': 24, 'PTO Hours': 16, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 2 days of leave.'}
# {'Name': 'Ashok Munagala', 'Location': 'India', 'Deficiency/Overtime in Hours': '+48.0', 'Total Time Logged': 176.0, 'Holiday Hours': 24, 'PTO Hours': 24, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Overtime of 48 hours logged.'}
# {'Name': 'Sampath Gattu', 'Location': 'India', 'Deficiency/Overtime in Hours': '-8.0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Chappidi Subba Raju', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 144 hours against required 152.'}
# {'Name': 'Deepak Devaraj', 'Location': 'US', 'Deficiency/Overtime in Hours': '+8.0', 'Total Time Logged': 176.0, 'Holiday Hours': 8, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Amol  Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Overtime of 8 hours logged against requirement of 168.'}
# {'Name': 'Sai Srinivas Potla', 'Location': 'India', 'Deficiency/Overtime in Hours': '+32.0', 'Total Time Logged': 152.0, 'Holiday Hours': 24, 'PTO Hours': 32, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged full month hours despite 4 days of leave.'}
# {'Name': 'Geethika Kakarla', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 136.0, 'Holiday Hours': 24, 'PTO Hours': 16, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 2 days of leave.'}
# {'Name': 'Narayana Reddy Bogireddy', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 136.0, 'Holiday Hours': 24, 'PTO Hours': 16, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 2 days of leave.'}
# {'Name': 'Apparao Buddha', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 1 day leave.'}
# {'Name': 'Ganesh Vallamla', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 136.0, 'Holiday Hours': 24, 'PTO Hours': 16, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 2 days leave.'}
# {'Name': 'Sriram Narayan', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Venkat Murthy Velamala', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 136.0, 'Holiday Hours': 24, 'PTO Hours': 16, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 2 days leave.'}
# {'Name': 'Chaitanya Dhanalakota', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Tejaswini Kande', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Subbaraju Chappidi', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Sirisha Achnala', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 152.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Chappidi Subba Raju', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements.'}
# {'Name': 'Siva Reddy Evuri', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Chappidi Subba Raju', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 1 day leave.'}
# {'Name': 'Kotla Pavani Priyanka', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 152.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Chappidi Subba Raju', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements.'}
# {'Name': 'SwamiNaidu Seepana', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 136.0, 'Holiday Hours': 24, 'PTO Hours': 16, 'Status': 'Approved', 'Manager': 'Chappidi Subba Raju', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 2 days leave.'}
# {'Name': 'Raghava Harshavardhan Raju', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 120.0, 'Holiday Hours': 24, 'PTO Hours': 32, 'Status': 'Approved', 'Manager': 'Chappidi Subba Raju', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 4 days leave.'}
# {'Name': 'Mohd Khaja Shujauddin', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Saiteja Ramagiri', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 1 day leave.'}
# {'Name': 'Tejaswani Kambampati', 'Location': 'India', 'Deficiency/Overtime in Hours': '-24.0', 'Total Time Logged': 108.0, 'Holiday Hours': 24, 'PTO Hours': 20, 'Status': 'Approved', 'Manager': 'Saiteja Ramagiri', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 108 hours against adjusted requirement of 132.'}
# {'Name': 'Keertipati Chandu Varma', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 128.0, 'Holiday Hours': 24, 'PTO Hours': 24, 'Status': 'Approved', 'Manager': 'Saiteja Ramagiri', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 3 days leave.'}
# {'Name': 'Chandana Gidugu', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 152.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Saiteja Ramagiri', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements.'}
# {'Name': 'Prajakta Shikare Maruti', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Saiteja Ramagiri', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 1 day leave.'}
# {'Name': 'Amar Sai Veeravalli', 'Location': 'India', 'Deficiency/Overtime in Hours': '-40.0', 'Total Time Logged': 96.0, 'Holiday Hours': 24, 'PTO Hours': 16, 'Status': 'Approved', 'Manager': 'Saiteja Ramagiri', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 96 hours out of adjusted required 136.'}
# {'Name': 'Sai Krishna Andhavarapu', 'Location': 'India', 'Deficiency/Overtime in Hours': '+16.0', 'Total Time Logged': 168.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Saiteja Ramagiri', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Overtime of 16 hours logged.'}
# {'Name': 'Anveshitha Thota', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 152.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Saiteja Ramagiri', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirement.'}
# {'Name': 'Nuty Vanitha', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Smruthi Kothakonda', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirement after 1 day leave.'}
# {'Name': 'Devadula Sai Sudheer', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Smruthi Kothakonda', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirement after 1 day leave.'}
# {'Name': 'Gouni Saideepthi', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Smruthi Kothakonda', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Bera Sireesha Krishnaveni', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Smruthi Kothakonda', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Venkata Lalitha Suresh Emani', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirement after 1 day leave.'}
# {'Name': 'Sindhu Pogula', 'Location': 'India', 'Deficiency/Overtime in Hours': '-36.0', 'Total Time Logged': 96.0, 'Holiday Hours': 24, 'PTO Hours': 20, 'Status': 'Open', 'Manager': 'Uday kiran Y', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 96 hours out of adjusted required 132.'}
# {'Name': 'Ramesh Bevara', 'Location': 'India', 'Deficiency/Overtime in Hours': '+8.0', 'Total Time Logged': 160.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Overtime of 8 hours logged.'}
# {'Name': 'Naresh Sowoju', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 128.0, 'Holiday Hours': 24, 'PTO Hours': 24, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirement after 3 days leave.'}
# {'Name': 'Rajeshwar', 'Location': 'India', 'Deficiency/Overtime in Hours': '-144.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Syam Sundar Devarakonda', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged despite 1 day of leave.'}
# {'Name': 'Pramod Kumar Kodoju', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Syam Devarakonda', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirement after 1 day leave.'}
# {'Name': 'Babita Kumar', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Syam Sundar Devarakonda', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Jesus Fernandez', 'Location': 'Spain', 'Deficiency/Overtime in Hours': '-40.0', 'Total Time Logged': 112.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Suman Kalyan', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 112 hours against monthly requirement of 152.'}
# {'Name': 'Vishal Kumar', 'Location': 'India', 'Deficiency/Overtime in Hours': '+28.0', 'Total Time Logged': 168.0, 'Holiday Hours': 24, 'PTO Hours': 12, 'Status': 'Approved', 'Manager': 'Angshuman Patra', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Overtime of 28 hours logged.'}
# {'Name': 'Syam Sundar Devarakonda', 'Location': 'India', 'Deficiency/Overtime in Hours': '-40.0', 'Total Time Logged': 104.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Angshuman Patra', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 104 hours out of adjusted required 144.'}
# {'Name': 'Sneha Sahu', 'Location': 'India', 'Deficiency/Overtime in Hours': '-52.0', 'Total Time Logged': 100.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Mohin Shaik', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 100 hours out of required 152.'}
# {'Name': 'Vaibhav Mittal', 'Location': 'India', 'Deficiency/Overtime in Hours': '-48.0', 'Total Time Logged': 104.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Bellum Sai Siva Rama', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 104 hours out of required 152.'}
# {'Name': 'Nikhil Sham Vanjari', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Sujikar Reddy Varidireddy', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Kontham Anand kumar', 'Location': 'India', 'Deficiency/Overtime in Hours': '-2.0', 'Total Time Logged': 142.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Bellum Sai Siva Rama', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 142 hours against adjusted required 144.'}
# {'Name': 'Shriyans Kandhagatla', 'Location': 'India', 'Deficiency/Overtime in Hours': '-2.716112', 'Total Time Logged': 149.283888, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Bellum Sai Siva Rama', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Slight deficiency in total hours logged.'}
# {'Name': 'Arya Pulkit', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Mohin Shaik', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 1 day leave.'}
# {'Name': 'Sreelakshmi Kammakattu', 'Location': 'India', 'Deficiency/Overtime in Hours': '-130.333333', 'Total Time Logged': 13.666667, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Only ~13.7 hours logged for the month.'}
# {'Name': 'Britney H', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Sujikar Reddy Varidireddy', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Sai Vyvaswath Bhupasamudram', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Mohin Shaik', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirement after 1 day leave.'}
# {'Name': 'Kriti Bhagat', 'Location': 'India', 'Deficiency/Overtime in Hours': '-81.117222', 'Total Time Logged': 70.882778, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Mohin Shaik', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 70.88 hours out of required 152.'}
# {'Name': 'Debopriyo Ghosh', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Sujikar Reddy Varidireddy', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'K Anjali Achary', 'Location': 'India', 'Deficiency/Overtime in Hours': '+32.0', 'Total Time Logged': 176.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Younus Shaik', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Overtime of 32 hours logged.'}
# {'Name': 'Meena Nagarajan', 'Location': 'US', 'Deficiency/Overtime in Hours': '-48.0', 'Total Time Logged': 120.0, 'Holiday Hours': 8, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Mohin Shaik', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 120 hours against requirement of 168.'}
# {'Name': 'Navdeep Singh', 'Location': 'India', 'Deficiency/Overtime in Hours': '-118.666667', 'Total Time Logged': 33.333333, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Sujay Kumar', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 33.33 hours out of required 152.'}
# {'Name': 'Jhanvi Sharma', 'Location': 'India', 'Deficiency/Overtime in Hours': '+24.416667', 'Total Time Logged': 176.416667, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Sujay Kumar', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Overtime of 24.42 hours logged.'}
# {'Name': 'Saloni Singh Andotra', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Sujay Kumar', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Anchal Bakshi', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Sujay Kumar', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Afrin Taj', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Sujay Kumar', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Sarika Sharma', 'Location': 'India', 'Deficiency/Overtime in Hours': '+25.054485', 'Total Time Logged': 177.054485, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Sujay Kumar', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Overtime of 25.05 hours logged.'}
# {'Name': 'MN Prasad Reddy', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Sujay Kumar', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Dakshina Murthy Karra', 'Location': 'US', 'Deficiency/Overtime in Hours': '-168.0', 'Total Time Logged': 0.0, 'Holiday Hours': 8, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Babita Kumar', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Adrian Paleacu', 'Location': 'Romania', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 160.0, 'Holiday Hours': 16, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Dakshina Murthy Karra', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match monthly requirement.'}
# {'Name': 'Gabriel Trautmann', 'Location': 'Romania', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 160.0, 'Holiday Hours': 16, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Dakshina Murthy Karra', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match monthly requirement.'}
# {'Name': 'Sidharth Kondapuram', 'Location': 'Spain', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Jesus Fernandez', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Akunuri Jai Tiru Ganesh', 'Location': 'India', 'Deficiency/Overtime in Hours': '-2.5', 'Total Time Logged': 121.5, 'Holiday Hours': 24, 'PTO Hours': 28, 'Status': 'Open', 'Manager': 'Manjrekar Manish Raj', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 121.5 hours against adjusted requirement of 124.'}
# {'Name': 'Abhirupa Sen', 'Location': 'US', 'Deficiency/Overtime in Hours': '-168.0', 'Total Time Logged': 0.0, 'Holiday Hours': 8, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Shayne Pinto', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Kotturi Supriya', 'Location': 'India', 'Deficiency/Overtime in Hours': '+0.166666', 'Total Time Logged': 144.166666, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Bellum Sai Siva Rama Krishna', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Slight overtime of 0.17 hours.'}
# {'Name': 'Sai Shiva Naga Gudla', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Bellum Sai Siva Rama', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirement after 1 day leave.'}
# {'Name': 'Sanket Khushal Patil', 'Location': 'India', 'Deficiency/Overtime in Hours': '-10.0', 'Total Time Logged': 134.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Bellum Sai Siva Rama', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 134 hours out of adjusted requirement of 144.'}
# {'Name': 'Vikram Dattatray Danvale', 'Location': 'India', 'Deficiency/Overtime in Hours': '-59.5', 'Total Time Logged': 84.5, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Bellum Sai Siva Rama', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 84.5 hours out of adjusted requirement of 144.'}
# {'Name': 'Rishi Soni', 'Location': 'India', 'Deficiency/Overtime in Hours': '-0.334445', 'Total Time Logged': 147.665555, 'Holiday Hours': 24, 'PTO Hours': 4, 'Status': 'Approved', 'Manager': 'Bellum Sai Siva Rama', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Slight deficiency in hours logged.'}
# {'Name': 'Suneel Kumar Reddy Vaka', 'Location': 'India', 'Deficiency/Overtime in Hours': '-32.0', 'Total Time Logged': 88.0, 'Holiday Hours': 24, 'PTO Hours': 32, 'Status': 'Approved', 'Manager': 'Bellum Sai Siva Rama', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 88 hours against adjusted requirement of 120.'}
# {'Name': 'Manish Gari', 'Location': 'India', 'Deficiency/Overtime in Hours': '+6.0', 'Total Time Logged': 150.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Bellum Sai Siva Rama', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 150 hours against adjusted requirement of 144.'}
# {'Name': 'Yassir Benhammou', 'Location': 'Spain', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 152.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Mohin Shaik', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirement.'}
# {'Name': 'Bommadevara Kavyabharathi', 'Location': 'India', 'Deficiency/Overtime in Hours': '-2.0', 'Total Time Logged': 122.0, 'Holiday Hours': 24, 'PTO Hours': 28, 'Status': 'Approved', 'Manager': 'Mohin Shaik', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 122 hours against adjusted requirement of 124.'}
# {'Name': 'Tejinderpal Singh Jadhav', 'Location': 'India', 'Deficiency/Overtime in Hours': '-96.0', 'Total Time Logged': 40.0, 'Holiday Hours': 24, 'PTO Hours': 16, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 40 hours against adjusted requirement of 136.'}
# {'Name': 'Rohit Kumar', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Mohin Shaik', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Shantanu Chaturvedi', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Mohin Shaik', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}
# {'Name': 'Venkata Santosh Krishna Teja Ghanta', 'Location': 'India', 'Deficiency/Overtime in Hours': '+8.0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 16, 'Status': 'Open', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 144 hours against adjusted requirement of 136.'}
# {'Name': 'Inguva Satyavenkata Sai Kumar', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 112.0, 'Holiday Hours': 24, 'PTO Hours': 40, 'Status': 'Approved', 'Manager': 'Mohin Shaik', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 5 days leave.'}
# {'Name': 'Chowdarapu Srivatsa', 'Location': 'India', 'Deficiency/Overtime in Hours': '-32.0', 'Total Time Logged': 120.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Mohin Shaik', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 120 hours out of required 152.'}
# {'Name': 'Heet Hiteshkumar Gorakhiya', 'Location': 'India', 'Deficiency/Overtime in Hours': '-135.75', 'Total Time Logged': 8.25, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Open', 'Manager': 'Sachin Chaudhari', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Only 8.25 hours logged.'}
# {'Name': 'Shaurya Prakash Singh', 'Location': 'India', 'Deficiency/Overtime in Hours': '-144.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'N/A', 'Manager': 'Mohin Shaik', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Applied for leave but logged no hours.'}
# {'Name': 'Rahul Holekeri', 'Location': 'India', 'Deficiency/Overtime in Hours': '-14.5', 'Total Time Logged': 121.5, 'Holiday Hours': 24, 'PTO Hours': 16, 'Status': 'Approved', 'Manager': 'Mohin Shaik', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 121.5 hours out of adjusted requirement of 136.'}
# {'Name': 'Suresh Babu Konapuram', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 136.0, 'Holiday Hours': 24, 'PTO Hours': 16, 'Status': 'Approved', 'Manager': 'Mohin Shaik', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements after 2 days leave.'}
# {'Name': 'Alessandro Tiberio', 'Location': 'Spain', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 152.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Open', 'Manager': 'Dakshina Murthy Karra', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirements.'}
# {'Name': 'Sowmya Kunapuli', 'Location': 'India', 'Deficiency/Overtime in Hours': '-8.0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'Approved', 'Manager': 'Mohin Shaik', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 144 hours out of required 152.'}
# {'Name': 'Raju Pasunuri', 'Location': 'India', 'Deficiency/Overtime in Hours': '0', 'Total Time Logged': 144.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Mohin Shaik', 'Validation Needed': 'No', 'Analysis of Deficiency': 'Logged hours match requirement after 1 day leave.'}
# {'Name': 'Ayush Kumar', 'Location': 'India', 'Deficiency/Overtime in Hours': '-8.0', 'Total Time Logged': 136.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 136 hours against adjusted requirement of 144.'}
# {'Name': 'Gurunath Kamale', 'Location': 'India', 'Deficiency/Overtime in Hours': '-8.0', 'Total Time Logged': 136.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Approved', 'Manager': 'Amol Patalay', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 136 hours against adjusted requirement of 144.'}
# {'Name': 'Srigiri Sai Manish', 'Location': 'India', 'Deficiency/Overtime in Hours': '-88.0', 'Total Time Logged': 56.0, 'Holiday Hours': 24, 'PTO Hours': 8, 'Status': 'Open', 'Manager': 'Mohin Shaik', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'Logged 56 hours out of adjusted requirement of 144.'}
# {'Name': 'Vaishnavi Anaboina', 'Location': 'India', 'Deficiency/Overtime in Hours': '-152.0', 'Total Time Logged': 0.0, 'Holiday Hours': 24, 'PTO Hours': 0, 'Status': 'N/A', 'Manager': 'Mohin Shaik', 'Validation Needed': 'Yes', 'Analysis of Deficiency': 'No hours logged.'}

# %%
df_report = pd.DataFrame(emp_lst)
df_report.head()
# Out:
#                         Name Location Deficiency/Overtime in Hours  \
# 0               Shayne Pinto       US                       -108.0
# 1              Tanishq Swami    India                       -152.0
# 2                       Amol    India                       -144.0
# 3           Sachin Chaudhari       US                       -168.0
# 4  Sujikar Reddy Varidireddy    India                        -24.0
#
#    Total Time Logged  Holiday Hours  PTO Hours Status  \
# 0               60.0              8          0   Open
# 1                0.0             24          0    N/A
# 2                0.0             24          8   Open
# 3                0.0              8          0    N/A
# 4              112.0             24         16   Open
#
#                      Manager Validation Needed  \
# 0             Ganesh Tyagali               Yes
# 1  Bommadevara Kavyabharathi               Yes
# 2               Vishal Kumar               Yes
# 3               Vishal Kumar               Yes
# 4               Vishal Kumar               Yes
#
#                               Analysis of Deficiency
# 0  Logged 60 hours out of the adjusted requiremen...
# 1                     No hours logged for the month.
# 2  Applied for 1 day of leave but logged 0 workin...
# 3                     No hours logged for the month.
# 4  Logged 112 hours against an adjusted requireme...

# %%
df_report.to_excel("Monthly_Report_January_2026.xlsx", index=False, sheet_name="January_2026")

# %%
import smtplib
from email.message import EmailMessage
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders

# %%
## sending the email
sender = os.getenv("EMAIL_USER")
password = os.getenv("EMAIL_PASS")
receiver = os.getenv("EMAIL_TO")
#receiver = "abhirupac.sen@gmail.com"

#smtp_server = "smtp.gmail.com"
#smtp_port = 465 

file_to_attach = "Monthly_Report_January_2026.xlsx"

try:
        

        body = "Hi Shayne, \n Attached is the table of defaulters created from the json file. I am sending this email from python code.\n\nThanks,\nAbhirupa"
        msg = MIMEMultipart()
        msg['Subject'] = "Timesheet Sheet Report for the month of January, 2026"
        msg['From'] = sender
        msg['To'] = receiver
        msg.attach(MIMEText(body, "plain"))

        part = MIMEBase("application", "vnd.openxmlformats-officedocument.spreadsheetml.sheet")

        with open(file_to_attach, "rb") as attachment:
            # MIMEBase handles binary files like Excel
            #part = MIMEBase("application", "octet-stream")
            part.set_payload(attachment.read())

        # Encode file in ASCII characters to send by email    
        encoders.encode_base64(part)
        part.add_header(
            "Content-Disposition",
            f'attachment; filename="{os.path.basename(file_to_attach)}"'
        )
        msg.attach(part)

        server = smtplib.SMTP("smtp.gmail.com", 587)
        server.starttls() # Secure the connection
        server.login(sender, password)
        server.send_message(msg)

except Exception as e:
        print(f"Failed to send emails: {e}")
